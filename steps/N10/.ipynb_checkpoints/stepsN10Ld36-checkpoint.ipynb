# %% [markdown]
# # Development rig

# %%
N,L_d=10,36
import sys

# setting path
sys.path.append('../')

import matplotlib.pyplot as plt
import numpy as np

from waterwaves1.wave import wave1
from waterwaves1.packing import unpack1,pack1
from waterwaves1.fourier import IEj
from waterwaves1.display import eta

# %%
Hmx_d=(0.141063*L_d+0.0095721*L_d**2+0.0077829*L_d**3)/(1+0.0788340*L_d+0.0317567*L_d**2+0.0093407*L_d**3)
d=2*np.pi/L_d
s=d*(1+0.0*Hmx_d)
X=np.linspace(0,np.pi,200)

# %%
def eta1(h):
    sol=wave1(N,h*Hmx_d*d,d=d,scaler=s)
    eta(X,d,sol,lab=f'h={h}')
    return sol
    
for h in np.linspace(0.2,0.95,6):
    eta1(h)
plt.legend()
plt.title(f'd={d:4.2f}')
plt.show()
# Out:
# h=0.35 fail
# h=0.6499999999999999 fail

# %%
def step(h1,h2,h3):
    sol1=wave1(N,h1*Hmx_d*d,d=d,scaler=s)
    sol2=wave1(N,h2*Hmx_d*d,d=d,scaler=s)
    Ej1,Q1,R1=unpack1(sol1.x)
    Ej2,Q2,R2=unpack1(sol2.x)
    A3=((h2-h3)*sol1.x+(h3-h1)*sol2.x)/(h2-h1)
    sol3=wave1(N,h3*Hmx_d*d,d=d,scaler=s,A0=A3)
    if not sol3.success:
        print(h3,'fail step 2')    
    return sol3

def eta2(h1,h2,h3):
    sol=step(h1,h2,h3)
    eta(X,d,sol,lab=f'h={h3}')
eta1(0.1)
eta1(0.2)
eta2(0.1,0.2,0.95)
plt.legend()
plt.show()

# %%
def E(H,k):
    SOL=[wave1(N,h*Hmx_d*d,d=d,scaler=s) for h in H]
    Ek=[sol.x[k-1] for sol in SOL]
    plt.plot(H,Ek,label=f'k={k}')

for k in range(1,6):
    E(np.linspace(0.01,0.99),k)
plt.legend()
plt.show()

# %%
def E2(H):
    SOL=[step(0.1,0.2,h) for h in H]
    return SOL

def Ek(SOL,k):
    return [sol.x[k-1] for sol in SOL]

H=np.linspace(0,1)
SOL=E2(H)
for k in list(range(1,6)):
    plt.plot(H,Ek(SOL,k),label=f'k={k}')

plt.legend()
plt.show()

# %%
h=0.98
sol=step(0.1,0.2,h)
Np=70
A0=np.insert(sol.x,-2,np.zeros(Np))
solNp=wave1(N+Np,h*Hmx_d*d,d=d,scaler=s,A0=A0)
eta(X,d,solNp,f'h3={h}')

# %%
solNp
# Out:
#  message: The solution converged.
#  success: True
#   status: 1
#      fun: [ 5.037e-13  1.114e-13 ...  9.881e-15 -1.665e-16]
#        x: [ 1.677e-02  1.540e-02 ...  8.727e-02  3.042e-01]
#   method: hybr
#     nfev: 269
#     fjac: [[-2.116e-01 -1.912e-01 ... -1.552e-01 -4.438e-01]
#            [-2.561e-01 -2.256e-01 ...  1.446e-01 -6.961e-02]
#            ...
#            [ 1.090e-01 -4.965e-01 ...  2.566e-02  9.100e-02]
#            [-1.166e-02  1.698e-03 ...  1.676e-02  1.652e-03]]
#        r: [-4.507e+00  6.919e-01 ... -4.953e+00 -1.550e-02]
#      qtf: [ 2.829e-12  3.320e-12 ...  4.624e-12 -1.835e-13]
