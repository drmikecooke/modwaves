# %% [markdown]
# # Development rig

# %%
import matplotlib.pyplot as plt
import numpy as np

from waterwaves1.wave import wave,wave1
from waterwaves1.packing import unpack,unpack1
from waterwaves1.fourier import IEj

# %%
L_d=12
Hmx_d=(0.141063*L_d+0.0095721*L_d**2+0.0077829*L_d**3)/(1+0.0788340*L_d+0.0317567*L_d**2+0.0093407*L_d**3)
d=2*np.pi/L_d
N,h,s=40,0.8,d*(1+0.12*Hmx_d)

# %%
sol=wave(N,h*Hmx_d*d,d=d,scaler=s)
sol1=wave1(N,h*Hmx_d*d,d=d,scaler=s)
sol.success,sol1.success
# Out:
# (True, True)

# %%
Ej,Bj,Ub,Q,R=unpack(sol.x)

Ej1,Q1,R1=unpack1(sol1.x)

# %%
X=np.linspace(0,np.pi)
plt.plot(X,IEj([d,*Ej[:6]],X),label=f"Ej")
plt.plot(X,IEj([d,*Ej1],X),label=f"Ej1")
plt.legend()

# %%
sol2=wave1(N,0.96*Hmx_d*d,d=d,scaler=s,A0=sol1.x)
Ej2,Q2,R2=unpack1(sol2.x)
plt.plot(X,IEj([d,*Ej2],X),label=f"Ej2")
plt.legend(),sol2.success
# Out:
# (<matplotlib.legend.Legend at 0x7f6b134250>, True)

# %%
sol3=wave1(N,0.97*Hmx_d*d,d=d,scaler=s,A0=sol2.x)
Ej3,Q3,R3=unpack1(sol3.x)
plt.plot(X,IEj([d,*Ej3],X),label=f"Ej3")
plt.legend(),sol3.success
# Out:
# (<matplotlib.legend.Legend at 0x7f68b55290>, True)

# %%
sol4=wave1(N,0.98*Hmx_d*d,d=d,scaler=s,A0=sol1.x)
Ej4,Q4,R4=unpack1(sol4.x)
plt.plot(X,IEj([d,*Ej4],X),label=f"Ej4")
plt.legend(),sol4.success
# Out:
# (<matplotlib.legend.Legend at 0x7f68b75f50>, True)

# %%
sol5=wave1(N,0.985*Hmx_d*d,d=d,scaler=s,A0=sol4.x)
Ej5,Q5,R5=unpack1(sol5.x)
plt.plot(X,IEj([d,*Ej5],X),label=f"Ej5")
plt.legend(),sol5.success
# Out:
# (<matplotlib.legend.Legend at 0x7f689e5b90>, True)

# %%
d
# Out:
# 0.5235987755982988

# %%
from waterwaves1.grids import grids

# %%
SS=d*(1+np.linspace(0,0.5)*Hmx_d)
Cnd=[]
for s in SS:
    g=grids(N,s)
    
    N=len(Ej)
    Etam=IEj([d,*Ej],g.Xm) # imposes depth constraint
    Etamj=Etam.reshape((N+1,1))@g.j.reshape((1,N))
    C,S=(np.exp,np.exp) if d==0 else (np.cosh,np.sinh) # hyperbolics for Y dependence, for deep water use exp
    CEmj,SEmj=C(Etamj)/g.scl,S(Etamj)/g.scl
    a=np.hstack([-Etam.reshape(N+1,1),(SEmj*g.CXmj)])
    UbBj=np.linalg.solve(a,-Q*np.ones(N+1)) # impose kinetic condition to derive Ub,Bj
    
    Cnd+=[np.linalg.cond(a)]

plt.plot(SS,Cnd)

# %%
d*(1+0.12*Hmx_d)
# Out:
# 0.5694061538670794

# %%
SS
# Out:
# array([0.52359878, 0.52749396, 0.53138915, 0.53528433, 0.53917952,
#        0.5430747 , 0.54696989, 0.55086507, 0.55476026, 0.55865544,
#        0.56255063, 0.56644581, 0.570341  , 0.57423618, 0.57813137,
#        0.58202655, 0.58592174, 0.58981692, 0.59371211, 0.59760729,
#        0.60150248, 0.60539767, 0.60929285, 0.61318804, 0.61708322,
#        0.62097841, 0.62487359, 0.62876878, 0.63266396, 0.63655915,
#        0.64045433, 0.64434952, 0.6482447 , 0.65213989, 0.65603507,
#        0.65993026, 0.66382544, 0.66772063, 0.67161581, 0.675511  ,
#        0.67940618, 0.68330137, 0.68719656, 0.69109174, 0.69498693,
#        0.69888211, 0.7027773 , 0.70667248, 0.71056767, 0.71446285])
